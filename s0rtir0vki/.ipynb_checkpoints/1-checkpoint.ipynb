# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.optimize as so
import csv


x_data, y_data = [], []
with open("bubble_sort.csv", encoding='utf-8') as r_file:
    
    file = csv.reader(r_file, delimiter = ";")
    count = 0
    for row in file:
        if count == 0:
            pass
        else:
            x_data.append(row[0])
            y_data.append(row[1])
        count += 1

                      
for i in range(0, len(x_data)):
    x_data[i] = float(x_data[i])
for i in range(0, len(y_data)):
    y_data[i] = float(y_data[i])

def f(x, a):
    y = a * x * x
    return y


G = so.curve_fit(f, x_data, y_data)
a1 = G[0][0]


y_new, x_new = [], []
for i in range(0, int(x_data[len(x_data)-1]), 20):
    x_new.append(i)
    y_new.append(f(i, a1))

plt.figure(figsize=(18, 10))
plt.plot(x_data, y_data, 'ro', label=r'experimental', color='orange')
plt.plot(x_new, y_new, label=r'theoretical', color='black', linewidth='3')
plt.xlabel(r'$N$', fontsize=14)
plt.ylabel(r'$Time,\  s$', fontsize=14)
plt.title(r'$bubble\  sort$', fontsize=16)
plt.legend(loc='best', fontsize=12)
plt.grid(True)

a1_string = str(round(a1*1000000, 1))
plt.text(0, 950, 'теоретическая зависимость: t = ' + a1_string + 'e-06 * N^2', fontsize = 20)
                      
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-e8b433e0648e> in <module>
#       6
#       7 x_data, y_data = [], []
# ----> 8 with open("bubble_sort.csv", encoding='utf-8') as r_file:
#       9
#      10     file = csv.reader(r_file, delimiter = ";")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bubble_sort.csv'

# %%
x_data, y_data = [], []
with open("shaker_sort.csv", encoding='utf-8') as r_file:
    
    file = csv.reader(r_file, delimiter = ";")
    count = 0
    for row in file:
        if count == 0:
            pass
        else:
            x_data.append(row[0])
            y_data.append(row[1])
        count += 1

                      
for i in range(0, len(x_data)):
    x_data[i] = float(x_data[i])
for i in range(0, len(y_data)):
    y_data[i] = float(y_data[i])

def f(x, a):
    y = a * x * x
    return y


G = so.curve_fit(f, x_data, y_data)
a2 = G[0][0]


y_new, x_new = [], []
for i in range(0, int(x_data[len(x_data)-1]), 20):
    x_new.append(i)
    y_new.append(f(i, a2))

plt.figure(figsize=(18, 10))
plt.plot(x_data, y_data, 'ro', label=r'experimental', color='orange')
plt.plot(x_new, y_new, label=r'theoretical', color='black', linewidth='3')
plt.xlabel(r'$N$', fontsize=14)
plt.ylabel(r'$Time,\  s$', fontsize=14)
plt.title(r'$shaker\  sort$', fontsize=16)
plt.legend(loc='best', fontsize=12)
plt.grid(True)

a2_string = str(round(a2*1000000, 1))
plt.text(0, 750, 'теоретическая зависимость: t = ' + a2_string + 'e-06 * N^2', fontsize = 20)
                      
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-1db28c1a8c9f> in <module>
#       1 x_data, y_data = [], []
# ----> 2 with open("shaker_sort.csv", encoding='utf-8') as r_file:
#       3
#       4     file = csv.reader(r_file, delimiter = ";")
#       5     count = 0
#
# FileNotFoundError: [Errno 2] No such file or directory: 'shaker_sort.csv'

# %%
x_data, y_data = [], []
with open("insert_sort.csv", encoding='utf-8') as r_file:
    
    file = csv.reader(r_file, delimiter = ";")
    count = 0
    for row in file:
        if count == 0:
            pass
        else:
            x_data.append(row[0])
            y_data.append(row[1])
        count += 1

                      
for i in range(0, len(x_data)):
    x_data[i] = float(x_data[i])
for i in range(0, len(y_data)):
    y_data[i] = float(y_data[i])

def f(x, a):
    y = a * x * x
    return y


G = so.curve_fit(f, x_data, y_data)
a3 = G[0][0]


y_new, x_new = [], []
for i in range(0, int(x_data[len(x_data)-1]), 20):
    x_new.append(i)
    y_new.append(f(i, a3))

plt.figure(figsize=(18, 10))
plt.plot(x_data, y_data, 'ro', label=r'experimental', color='orange')
plt.plot(x_new, y_new, label=r'theoretical', color='black', linewidth='3')
plt.xlabel(r'$N$', fontsize=14)
plt.ylabel(r'$Time,\  s$', fontsize=14)
plt.title(r'$insert\  sort$', fontsize=16)
plt.legend(loc='best', fontsize=12)
plt.grid(True)

a3_string = str(round(a3*1000000, 1))
plt.text(0, 425, 'теоретическая зависимость: t = ' + a3_string + 'e-06 * N^2', fontsize = 20)
                      
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-ad319482b7a9> in <module>
#       1 x_data, y_data = [], []
# ----> 2 with open("insert_sort.csv", encoding='utf-8') as r_file:
#       3
#       4     file = csv.reader(r_file, delimiter = ";")
#       5     count = 0
#
# FileNotFoundError: [Errno 2] No such file or directory: 'insert_sort.csv'

# %%
x_data, y_data = [], []
with open("stupid_sort.csv", encoding='utf-8') as r_file:
    
    file = csv.reader(r_file, delimiter = ";")
    count = 0
    for row in file:
        if count == 0:
            pass
        else:
            x_data.append(row[0])
            y_data.append(row[1])
        count += 1

                      
for i in range(0, len(x_data)):
    x_data[i] = float(x_data[i])
for i in range(0, len(y_data)):
    y_data[i] = float(y_data[i])

def f4(x, a):
    y = a * x * x * x
    return y


G = so.curve_fit(f4, x_data, y_data)
a4 = G[0][0]


y_new, x_new = [], []
for i in range(0, int(x_data[len(x_data)-1]), 20):
    x_new.append(i)
    y_new.append(f4(i, a4))

plt.figure(figsize=(18, 10))
plt.plot(x_data, y_data, 'ro', label=r'experimental', color='orange')
plt.plot(x_new, y_new, label=r'theoretical', color='black', linewidth='3')
plt.xlabel(r'$N$', fontsize=14)
plt.ylabel(r'$Time,\  s$', fontsize=14)
plt.title(r'$stupid\  sort$', fontsize=16)
plt.legend(loc='best', fontsize=12)
plt.grid(True)

a4_string = str(round(a4*1000000, 1))
plt.text(0, 1900, 'теоретическая зависимость: t = ' + a4_string + 'e-06 * N^3', fontsize = 20)
                      
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-8f349ac2e5ad> in <module>
#       1 x_data, y_data = [], []
# ----> 2 with open("stupid_sort.csv", encoding='utf-8') as r_file:
#       3
#       4     file = csv.reader(r_file, delimiter = ";")
#       5     count = 0
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stupid_sort.csv'

# %%
x_data, y_data = [], []
with open("Shell_sort.csv", encoding='utf-8') as r_file:
    
    file = csv.reader(r_file, delimiter = ";")
    count = 0
    for row in file:
        if count == 0:
            pass
        else:
            x_data.append(row[0])
            y_data.append(row[1])
        count += 1

                      
for i in range(0, len(x_data)):
    x_data[i] = float(x_data[i])
for i in range(0, len(y_data)):
    y_data[i] = float(y_data[i])

def f1(x, a, b):
    y = a * x ** b
    return y


G = so.curve_fit(f1, x_data, y_data)
G = G[0]
a, b = G[0], G[1]


y_new, x_new = [], []
for i in range(0, int(x_data[len(x_data)-1]), 20):
    x_new.append(i)
    y_new.append(f1(i, a, b))
    
plt.figure(figsize=(18, 10))
plt.plot(x_data, y_data, 'ro', label=r'experimental', color='orange')
plt.plot(x_new, y_new, label=r'theoretical', color='black', linewidth='3')
plt.xlabel(r'$N$', fontsize=14)
plt.ylabel(r'$Time,\  s$', fontsize=14)
plt.title(r'$Shell\  sort$', fontsize=16)
plt.legend(loc='best', fontsize=12)
plt.grid(True)

a_string = str(round(a*1000000, 1))
b_string = str(round(b, 1))
plt.text(0, 240, 'теоретическая зависимость: t = ' + a_string + 'e-06 * ' + b_string, fontsize = 20)
                      
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-a2b588ee9556> in <module>
#       1 x_data, y_data = [], []
# ----> 2 with open("Shell_sort.csv", encoding='utf-8') as r_file:
#       3
#       4     file = csv.reader(r_file, delimiter = ";")
#       5     count = 0
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Shell_sort.csv'

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.optimize as so
import csv


x_data, y_data = [], []
with open("std_sort.csv", encoding='utf-8') as r_file:
    
    file = csv.reader(r_file, delimiter = ";")
    count = 0
    for row in file:
        if count == 0:
            pass
        else:
            x_data.append(row[0])
            y_data.append(row[1])
        count += 1

                      
for i in range(0, len(x_data)):
    x_data[i] = float(x_data[i])
for i in range(0, len(y_data)):
    y_data[i] = float(y_data[i])

def f2(x, a):
    y = a * x * np.log(x)
    return y


G = so.curve_fit(f2, x_data, y_data)
a6 = G[0][0]


y_new, x_new = [], []
for i in range(0, int(x_data[len(x_data)-1]), 20):
    x_new.append(i)
    y_new.append(f2(i, a6))

plt.figure(figsize=(18, 10))
plt.plot(x_data, y_data, 'ro', label=r'experimental', color='orange')
plt.plot(x_new, y_new, label=r'theoretical', color='black', linewidth='3')
plt.xlabel(r'$N$', fontsize=14)
plt.ylabel(r'$Time,\  s$', fontsize=14)
plt.title(r'$std\  sort$', fontsize=16)
plt.legend(loc='best', fontsize=12)
plt.grid(True)

a6_string = str(round(a6*100000, 1))
plt.text(0, 260, 'теоретическая зависимость: t = ' + a6_string + 'e-05 * NlnN', fontsize = 20)
                      
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-1e4971a85936> in <module>
#      29
#      30
# ---> 31 G = so.curve_fit(f2, x_data, y_data)
#      32 a6 = G[0][0]
#      33
#
# c:\users\mari78\appdata\local\programs\python\python39\lib\site-packages\scipy\optimize\minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     745
#     746     if ydata.size == 0:
# --> 747         raise ValueError("`ydata` must not be empty!")
#     748
#     749     # Determine type of sigma
#
# ValueError: `ydata` must not be empty!

# %%
X1, X2, X3, X4, X5, X6 = [], [], [], [], [], []
Y1, Y2, Y3, Y4, Y5, Y6 = [], [], [], [], [], []
for i in range(0, 20000, 100):
    for J in (X1, X2, X3, X4, X5, X6):
        J.append(i)
    Y1.append(f(i, a1))
    Y2.append(f(i, a2)) 
    Y3.append(f(i, a3)) 
    Y4.append(f4(i, a4))
    Y5.append(f1(i, a, b))
    Y6.append(f2(i, a6)) 

plt.figure(figsize=(18, 10))
plt.plot(X1, Y1, 'ro', label=r'bubble')
plt.plot(X2, Y2, 'ro', label=r'shaker')
plt.plot(X3, Y3, 'ro', label=r'insert')
plt.plot(X4, Y4, 'ro', label=r'stupid')
plt.plot(X5, Y5, 'ro', label=r'Shell')
plt.plot(X6, Y6, 'ro', label=r'std::sort')
plt.xlabel(r'$N$', fontsize=14)
plt.ylabel(r'$Time,\  s$', fontsize=14)
plt.title(r'$all sorts$', fontsize=16)
plt.legend(loc='best', fontsize=12)
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9f66dd14bf0d> in <module>
#       4     for J in (X1, X2, X3, X4, X5, X6):
#       5         J.append(i)
# ----> 6     Y1.append(f(i, a1))
#       7     Y2.append(f(i, a2))
#       8     Y3.append(f(i, a3))
#
# NameError: name 'f' is not defined
